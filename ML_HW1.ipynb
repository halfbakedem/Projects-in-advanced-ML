# %% [markdown]
# <a href="https://colab.research.google.com/github/halfbakedem/Projects-in-advanced-ML/blob/main/ML_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setting up and preprocessing data

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aimodelshare
#   Downloading aimodelshare-0.0.178-py3-none-any.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.0/967.0 KB 11.7 MB/s eta 0:00:00
# Collecting botocore==1.24.20
#   Downloading botocore-1.24.20-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 23.6 MB/s eta 0:00:00
# Collecting importlib-resources==5.10.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.13.1-cp38-cp38-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 14.4 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.3.0)
# Collecting boto3==1.21.20
#   Downloading boto3-1.21.20-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 3.5 MB/s eta 0:00:00
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 KB 4.3 MB/s eta 0:00:00
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 7.9 MB/s eta 0:00:00
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 13.1 MB/s eta 0:00:00
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 1.4 MB/s eta 0:00:00
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 KB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.6.3)
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 KB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2022.6.2)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.11.2)
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2.9.2)
# Collecting tf2onnx
#   Downloading tf2onnx-1.13.0-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 KB 9.0 MB/s eta 0:00:00
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 KB 4.2 MB/s eta 0:00:00
# Collecting skl2onnx>=1.8.0
#   Downloading skl2onnx-1.13-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 KB 13.4 MB/s eta 0:00:00
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.0.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.1+cu116)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (0.38.4)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 3.8 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.5.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.8/dist-packages (from docker==5.0.0->aimodelshare) (2.25.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources==5.10.0->aimodelshare) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (4.4.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (57.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.1.2)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.12)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.30.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (15.0.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (23.0)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (1.7.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (3.2.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (1.3.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2022.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (4.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (6.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164822 sha256=22b98db45c1ad96e420e0446e5fe47b981476fed37e4e249f885d3604af2d405
#   Stored in directory: /root/.cache/pip/wheels/24/6f/0b/da9f81234859a8741aaea3afcc6ae2daf0efb67e7ff2d3686c
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=056a2a1d6864d5f331b3951d0ab15a7f4faf4bab1526c3da83601a597fe1714f
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=34d86f89608a1a851d6a68eeff3aacba5e1e9f0a12b23362a1e53315e4dacf92
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built Pympler wget fire
# Installing collected packages: wget, Pympler, websocket-client, urllib3, shortuuid, PyJWT, psutil, onnx, jmespath, importlib-resources, humanfriendly, fire, scikit-learn, onnxconverter-common, coloredlogs, botocore, tf2onnx, skl2onnx, s3transfer, onnxruntime, keras2onnx, docker, onnxmltools, boto3, aimodelshare
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.10.2
#     Uninstalling importlib-resources-5.10.2:
#       Successfully uninstalled importlib-resources-5.10.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed PyJWT-2.6.0 Pympler-0.9 aimodelshare-0.0.178 boto3-1.21.20 botocore-1.24.20 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 humanfriendly-10.0 importlib-resources-5.10.0 jmespath-0.10.0 keras2onnx-1.7.0 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.1 onnxruntime-1.13.1 psutil-5.9.4 s3transfer-0.5.2 scikit-learn-0.24.2 shortuuid-1.0.11 skl2onnx-1.13 tf2onnx-1.13.0 urllib3-1.26.14 websocket-client-1.5.0 wget-3.2

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/My Drive/advanced ML')
# Out:
# Mounted at /content/drive

# %%
#Get competition data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
#Save preprocessor
import aimodelshare as ai

ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# Set up modelshare.org

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %% [markdown]
# Model 1: Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid1 = {'n_estimators': np.arange(25, 200, 25),'max_depth':[1, 3, 5, 7]} 

model1 = GridSearchCV(RandomForestClassifier(), param_grid=param_grid1, cv=10)

#use meta model methods to fit score and predict model:
model1.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(model1.best_score_))
print("best parameters: {}".format(model1.best_params_))
# Out:
# best mean cross-validation score: 0.704
# best parameters: {'max_depth': 7, 'n_estimators': 75}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model1, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (Model 1)
prediction_labels = model1.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 261
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# Model 2: Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np


param_grid = {'n_estimators': np.arange(50, 300, 25), 'learning_rate':[0.6,0.8,1], 'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

model2 = GridSearchCV(GradientBoostingClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
model2.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(model2.best_score_))
print("best parameters: {}".format(model2.best_params_))
# Out:
# best mean cross-validation score: 0.675
# best parameters: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 200}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model2.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 208
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# Model 3: Tensor flow

# %%
# Import relevant modules from TensorFlow
import tensorflow as tf
from tensorflow.keras import layers

# define the model architecture
model3 = tf.keras.Sequential()

# add the first convolutional layer with 16 filters and 'relu' activation
model3.add(tf.keras.layers.Conv2D(16, (4, 4), activation='relu'))

# add max pooling with a 2 by 2 filter
model3.add(tf.keras.layers.MaxPooling2D((4, 4)))

# add the second convolutional layer with 28 filters and 'relu' activation
model3.add(tf.keras.layers.Conv2D(28, (3, 3), activation='relu'))

# add max pooling with a 2 by 2 filter
model3.add(tf.keras.layers.MaxPooling2D((4, 4)))

# add the output layer with 'softmax' activation
model3.add(tf.keras.layers.Dense(5, activation='softmax'))

# compile the model using 'sgd' optimizer
model3.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Import relevant modules from TensorFlow
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD


model3 = Sequential([
    Dense(32, input_dim=(26)),
    Activation('relu'),
    Dense(32),
    Activation('relu'),
    Dense(32),
    Activation('relu'),
    Dense(5),
    Activation('softmax'),
])

# compile the model using 'sgd' optimizer
model3.compile(optimizer='sgd', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# fitting the model
import numpy as np
tf.config.run_functions_eagerly(True)
model3.fit(preprocessor(X_train), y_train, validation_split=0.25, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1916 - accuracy: 0.9545 - val_loss: 1.2864 - val_accuracy: 0.6364
# Epoch 2/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1888 - accuracy: 0.9394 - val_loss: 1.3032 - val_accuracy: 0.6364
# Epoch 3/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1901 - accuracy: 0.9545 - val_loss: 1.3107 - val_accuracy: 0.6364
# Epoch 4/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1854 - accuracy: 0.9545 - val_loss: 1.3161 - val_accuracy: 0.6364
# Epoch 5/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1888 - accuracy: 0.9394 - val_loss: 1.3225 - val_accuracy: 0.6364
# Epoch 6/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1864 - accuracy: 0.9545 - val_loss: 1.3400 - val_accuracy: 0.6364
# Epoch 7/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1834 - accuracy: 0.9545 - val_loss: 1.3366 - val_accuracy: 0.6364
# Epoch 8/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1843 - accuracy: 0.9545 - val_loss: 1.3428 - val_accuracy: 0.6364
# Epoch 9/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1797 - accuracy: 0.9545 - val_loss: 1.3485 - val_accuracy: 0.6364
# Epoch 10/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1799 - accuracy: 0.9545 - val_loss: 1.3529 - val_accuracy: 0.6364
# Epoch 11/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1793 - accuracy: 0.9545 - val_loss: 1.3367 - val_accuracy: 0.6364
# Epoch 12/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1783 - accuracy: 0.9545 - val_loss: 1.3493 - val_accuracy: 0.6364
# Epoch 13/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1754 - accuracy: 0.9545 - val_loss: 1.3605 - val_accuracy: 0.6364
# Epoch 14/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1770 - accuracy: 0.9545 - val_loss: 1.3671 - val_accuracy: 0.6364
# Epoch 15/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1748 - accuracy: 0.9545 - val_loss: 1.3729 - val_accuracy: 0.6364
# Epoch 16/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1715 - accuracy: 0.9545 - val_loss: 1.3655 - val_accuracy: 0.6364
# Epoch 17/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1708 - accuracy: 0.9545 - val_loss: 1.3836 - val_accuracy: 0.6364
# Epoch 18/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1715 - accuracy: 0.9545 - val_loss: 1.3931 - val_accuracy: 0.6364
# Epoch 19/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1705 - accuracy: 0.9545 - val_loss: 1.3967 - val_accuracy: 0.6364
# Epoch 20/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1700 - accuracy: 0.9545 - val_loss: 1.3947 - val_accuracy: 0.6364
# Epoch 21/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1669 - accuracy: 0.9545 - val_loss: 1.4018 - val_accuracy: 0.6364
# Epoch 22/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1643 - accuracy: 0.9545 - val_loss: 1.4016 - val_accuracy: 0.6364
# Epoch 23/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1657 - accuracy: 0.9545 - val_loss: 1.3998 - val_accuracy: 0.6364
# Epoch 24/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1639 - accuracy: 0.9545 - val_loss: 1.3922 - val_accuracy: 0.6364
# Epoch 25/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1651 - accuracy: 0.9545 - val_loss: 1.3988 - val_accuracy: 0.6364
# Epoch 26/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1631 - accuracy: 0.9545 - val_loss: 1.3835 - val_accuracy: 0.6364
# Epoch 27/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.
200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0742 - accuracy: 0.9848 - val_loss: 1.9518 - val_accuracy: 0.5909
# Epoch 178/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0731 - accuracy: 0.9697 - val_loss: 1.9705 - val_accuracy: 0.5909
# Epoch 179/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0726 - accuracy: 0.9697 - val_loss: 1.9491 - val_accuracy: 0.5909
# Epoch 180/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0720 - accuracy: 0.9697 - val_loss: 1.9629 - val_accuracy: 0.5909
# Epoch 181/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0720 - accuracy: 0.9697 - val_loss: 1.9755 - val_accuracy: 0.5909
# Epoch 182/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0717 - accuracy: 0.9697 - val_loss: 1.9559 - val_accuracy: 0.5909
# Epoch 183/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0710 - accuracy: 0.9697 - val_loss: 1.9298 - val_accuracy: 0.5909
# Epoch 184/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0703 - accuracy: 0.9848 - val_loss: 1.9613 - val_accuracy: 0.5909
# Epoch 185/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0698 - accuracy: 0.9697 - val_loss: 1.9479 - val_accuracy: 0.5909
# Epoch 186/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0701 - accuracy: 0.9848 - val_loss: 1.9585 - val_accuracy: 0.5909
# Epoch 187/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0691 - accuracy: 1.0000 - val_loss: 1.9682 - val_accuracy: 0.5909
# Epoch 188/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0687 - accuracy: 0.9697 - val_loss: 1.9369 - val_accuracy: 0.5909
# Epoch 189/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 1.9670 - val_accuracy: 0.5909
# Epoch 190/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0685 - accuracy: 0.9848 - val_loss: 1.9730 - val_accuracy: 0.5909
# Epoch 191/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0692 - accuracy: 0.9848 - val_loss: 1.9805 - val_accuracy: 0.5909
# Epoch 192/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0678 - accuracy: 0.9848 - val_loss: 1.9733 - val_accuracy: 0.5909
# Epoch 193/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0673 - accuracy: 0.9848 - val_loss: 1.9966 - val_accuracy: 0.5909
# Epoch 194/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0662 - accuracy: 0.9848 - val_loss: 2.0045 - val_accuracy: 0.5909
# Epoch 195/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0667 - accuracy: 0.9697 - val_loss: 1.9982 - val_accuracy: 0.5909
# Epoch 196/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0670 - accuracy: 0.9848 - val_loss: 2.0104 - val_accuracy: 0.5909
# Epoch 197/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0670 - accuracy: 0.9848 - val_loss: 2.0067 - val_accuracy: 0.5909
# Epoch 198/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 2.0066 - val_accuracy: 0.5909
# Epoch 199/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 2.0179 - val_accuracy: 0.5909
# Epoch 200/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0643 - accuracy: 0.9848 - val_loss: 2.0247 - val_accuracy: 0.5909

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model3, framework='keras',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels=model3.predict(preprocessor(X_test))
prediction_labels=np.argmax(prediction_labels,axis=-1)
labels = {0: 'Average', 1: 'High', 2: 'Low', 3: 'Very High', 4: 'Very Low'}
prediction_labels = [labels[i] for i in prediction_labels]


# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})
# Out:
# 3/3 [==============================] - 0s 6ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 267
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# #Part 2: Improving place on leaderboard!

# %% [markdown]
# Model 4: Random Forest
#
# Using Anne's parameters to improve model.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

model4 = RandomForestClassifier(n_estimators=200, max_depth=7)

#use meta model methods to fit score and predict model:
model4.fit(preprocessor(X_train), y_train_labels)
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=200)

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model4, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 4: 

#-- Generate predicted values (Model 4)
prediction_labels = model4.predict(preprocessor(X_test))

# Submit Model 4 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})

##F1: 0.49, model version 271; did not improve:(
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 271
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# Model 5: improved Gradient Boost
#
# Using Oliver's parameters for gradient boosting to improve my f1 score.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np



model5 = GradientBoostingClassifier(n_estimators=52, learning_rate=1.115, max_depth=1)

#use meta model methods to fit score and predict model:
model5.fit(preprocessor(X_train), y_train_labels)
# Out:
# GradientBoostingClassifier(learning_rate=1.115, max_depth=1, n_estimators=52)

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model5, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model5.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})

##F1: 0.487, model version 270; improved:)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 269
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# Model 6: Neural Network
#
# None of my teammates attempted a 3-layer NN. I think that continuing down the path of 3-layer NN is the right one as my model generated the highest F1 score amongst my teammates. However, I did learn that I could perhaps increase the epochs and batch size.

# %%
# Import relevant modules from TensorFlow
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD


model6 = Sequential([
    Dense(32, input_dim=(26)),
    Activation('relu'),
    Dense(32),
    Activation('relu'),
    Dense(32),
    Activation('relu'),
    Dense(5),
    Activation('softmax'),
])

# compile the model using 'sgd' optimizer
model6.compile(optimizer='sgd', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# fitting the model
import numpy as np
tf.config.run_functions_eagerly(True)
model6.fit(preprocessor(X_train), y_train, validation_split=0.25, epochs=300, batch_size=30)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 0s 115ms/step - loss: 1.6260 - accuracy: 0.1515 - val_loss: 1.6419 - val_accuracy: 0.1818
# Epoch 2/300
# 3/3 [==============================] - 0s 69ms/step - loss: 1.6192 - accuracy: 0.1364 - val_loss: 1.6370 - val_accuracy: 0.1364
# Epoch 3/300
# 3/3 [==============================] - 0s 67ms/step - loss: 1.6135 - accuracy: 0.1818 - val_loss: 1.6317 - val_accuracy: 0.1818
# Epoch 4/300
# 3/3 [==============================] - 0s 61ms/step - loss: 1.6065 - accuracy: 0.1970 - val_loss: 1.6280 - val_accuracy: 0.1818
# Epoch 5/300
# 3/3 [==============================] - 0s 62ms/step - loss: 1.6014 - accuracy: 0.2121 - val_loss: 1.6235 - val_accuracy: 0.2273
# Epoch 6/300
# 3/3 [==============================] - 0s 74ms/step - loss: 1.5956 - accuracy: 0.2273 - val_loss: 1.6187 - val_accuracy: 0.2273
# Epoch 7/300
# 3/3 [==============================] - 0s 87ms/step - loss: 1.5892 - accuracy: 0.2273 - val_loss: 1.6115 - val_accuracy: 0.2273
# Epoch 8/300
# 3/3 [==============================] - 0s 77ms/step - loss: 1.5828 - accuracy: 0.2273 - val_loss: 1.6064 - val_accuracy: 0.2727
# Epoch 9/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5771 - accuracy: 0.2424 - val_loss: 1.6020 - val_accuracy: 0.2727
# Epoch 10/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5713 - accuracy: 0.2727 - val_loss: 1.5986 - val_accuracy: 0.3182
# Epoch 11/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5658 - accuracy: 0.2879 - val_loss: 1.5953 - val_accuracy: 0.3182
# Epoch 12/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5608 - accuracy: 0.3030 - val_loss: 1.5911 - val_accuracy: 0.3182
# Epoch 13/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.5553 - accuracy: 0.2879 - val_loss: 1.5860 - val_accuracy: 0.3182
# Epoch 14/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5486 - accuracy: 0.2879 - val_loss: 1.5815 - val_accuracy: 0.3182
# Epoch 15/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.5436 - accuracy: 0.2879 - val_loss: 1.5771 - val_accuracy: 0.3182
# Epoch 16/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5388 - accuracy: 0.3030 - val_loss: 1.5725 - val_accuracy: 0.3182
# Epoch 17/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5321 - accuracy: 0.3030 - val_loss: 1.5679 - val_accuracy: 0.3182
# Epoch 18/300
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5261 - accuracy: 0.3485 - val_loss: 1.5615 - val_accuracy: 0.3182
# Epoch 19/300
# 3/3 [==============================] - 0s 44ms/step - loss: 1.5188 - accuracy: 0.3485 - val_loss: 1.5562 - val_accuracy: 0.3182
# Epoch 20/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1
300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6957 - accuracy: 0.7576 - val_loss: 1.0816 - val_accuracy: 0.5000
# Epoch 191/300
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6941 - accuracy: 0.7424 - val_loss: 1.0849 - val_accuracy: 0.5000
# Epoch 192/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6897 - accuracy: 0.7424 - val_loss: 1.0876 - val_accuracy: 0.4545
# Epoch 193/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6878 - accuracy: 0.7273 - val_loss: 1.0911 - val_accuracy: 0.4545
# Epoch 194/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6851 - accuracy: 0.7424 - val_loss: 1.0874 - val_accuracy: 0.5000
# Epoch 195/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6830 - accuracy: 0.7424 - val_loss: 1.0819 - val_accuracy: 0.5000
# Epoch 196/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6830 - accuracy: 0.7576 - val_loss: 1.0813 - val_accuracy: 0.5000
# Epoch 197/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6777 - accuracy: 0.7576 - val_loss: 1.0859 - val_accuracy: 0.5000
# Epoch 198/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6769 - accuracy: 0.7576 - val_loss: 1.0752 - val_accuracy: 0.5000
# Epoch 199/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6746 - accuracy: 0.7879 - val_loss: 1.0725 - val_accuracy: 0.5000
# Epoch 200/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6727 - accuracy: 0.7879 - val_loss: 1.0809 - val_accuracy: 0.5000
# Epoch 201/300
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6691 - accuracy: 0.7727 - val_loss: 1.0852 - val_accuracy: 0.5455
# Epoch 202/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6658 - accuracy: 0.7576 - val_loss: 1.0897 - val_accuracy: 0.5000
# Epoch 203/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6638 - accuracy: 0.7424 - val_loss: 1.0855 - val_accuracy: 0.5455
# Epoch 204/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6609 - accuracy: 0.7576 - val_loss: 1.0748 - val_accuracy: 0.5455
# Epoch 205/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6592 - accuracy: 0.7879 - val_loss: 1.0777 - val_accuracy: 0.5455
# Epoch 206/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6574 - accuracy: 0.7727 - val_loss: 1.0893 - val_accuracy: 0.5000
# Epoch 207/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6531 - accuracy: 0.7727 - val_loss: 1.0755 - val_accuracy: 0.5455
# Epoch 208/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6510 - accuracy: 0.7879 - val_loss: 1.0833 - val_accuracy: 0.5000
# Epoch 209/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6483 - accuracy: 0.7879 - val_loss: 1.0730 - val_accuracy: 0.5000
# Epoch 210/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6459 - accuracy: 0.7879 - val_loss: 1.0768 - val_accuracy: 0.5000
# Epoch 211/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6425 - accuracy: 0.7879 - val_loss: 1.0735 - val_accuracy: 0.5455
# Epoch 212/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6409 - accuracy: 0.8030 - val_loss: 1.0716 - val_accuracy: 0.5455
# Epoch 213/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6386 - accuracy: 0.7879 - val_loss: 1.0681 - val_accuracy: 0.5455
# Epoch 214/300
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6360 - accuracy: 0.8030 - val_loss: 1.0696 - val_accuracy: 0.5455
# Epoch 215/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6335 - accuracy: 0.7727 - val_loss: 1.0702 - val_accuracy: 0.5455
# Epoch 216/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6317 - accuracy: 0.7879 - val_loss: 1.0664 - val_accuracy: 0.5455
# Epoch 217/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6289 - accuracy: 0.7879 - val_loss: 1.0655 - val_accuracy: 0.5455
# Epoch 218/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.
300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5206 - accuracy: 0.8485 - val_loss: 1.0496 - val_accuracy: 0.5909
# Epoch 279/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5200 - accuracy: 0.8485 - val_loss: 1.0497 - val_accuracy: 0.5909
# Epoch 280/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5172 - accuracy: 0.8485 - val_loss: 1.0513 - val_accuracy: 0.5909
# Epoch 281/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5158 - accuracy: 0.8333 - val_loss: 1.0527 - val_accuracy: 0.5909
# Epoch 282/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5154 - accuracy: 0.8485 - val_loss: 1.0498 - val_accuracy: 0.5909
# Epoch 283/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5131 - accuracy: 0.8485 - val_loss: 1.0441 - val_accuracy: 0.5909
# Epoch 284/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5119 - accuracy: 0.8333 - val_loss: 1.0523 - val_accuracy: 0.5909
# Epoch 285/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5110 - accuracy: 0.8333 - val_loss: 1.0500 - val_accuracy: 0.5909
# Epoch 286/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5088 - accuracy: 0.8333 - val_loss: 1.0565 - val_accuracy: 0.5909
# Epoch 287/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5079 - accuracy: 0.8485 - val_loss: 1.0510 - val_accuracy: 0.5909
# Epoch 288/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5069 - accuracy: 0.8333 - val_loss: 1.0419 - val_accuracy: 0.5455
# Epoch 289/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5064 - accuracy: 0.8485 - val_loss: 1.0388 - val_accuracy: 0.5909
# Epoch 290/300
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5074 - accuracy: 0.8485 - val_loss: 1.0366 - val_accuracy: 0.5909
# Epoch 291/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5041 - accuracy: 0.8485 - val_loss: 1.0361 - val_accuracy: 0.5909
# Epoch 292/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5026 - accuracy: 0.8182 - val_loss: 1.0346 - val_accuracy: 0.5455
# Epoch 293/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5013 - accuracy: 0.8182 - val_loss: 1.0385 - val_accuracy: 0.5909
# Epoch 294/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4985 - accuracy: 0.8182 - val_loss: 1.0348 - val_accuracy: 0.5909
# Epoch 295/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4985 - accuracy: 0.8182 - val_loss: 1.0401 - val_accuracy: 0.5909
# Epoch 296/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4953 - accuracy: 0.8182 - val_loss: 1.0437 - val_accuracy: 0.5909
# Epoch 297/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4944 - accuracy: 0.8333 - val_loss: 1.0465 - val_accuracy: 0.5455
# Epoch 298/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4922 - accuracy: 0.8182 - val_loss: 1.0474 - val_accuracy: 0.5455
# Epoch 299/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4916 - accuracy: 0.8485 - val_loss: 1.0525 - val_accuracy: 0.5455
# Epoch 300/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4911 - accuracy: 0.8333 - val_loss: 1.0543 - val_accuracy: 0.5455

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model6, framework='keras',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels=model6.predict(preprocessor(X_test))
prediction_labels=np.argmax(prediction_labels,axis=-1)
labels = {0: 'Average', 1: 'High', 2: 'Low', 3: 'Very High', 4: 'Very Low'}
prediction_labels = [labels[i] for i in prediction_labels]


# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})

#F1: 0.482, model version 272; improved!!!
# Out:
# 3/3 [==============================] - 0s 7ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 272
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_4ef89_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 58.8%, transparent 58.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_4ef89_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 57.7%, transparent 57.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_4ef89_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 65.6%, transparent 65.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_4ef89_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 59.5%, transparent 59.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_4ef89_row0_col4, #T_4ef89_row0_col5, #T_4ef89_row0_col6, #T_4ef89_row0_col7, #T_4ef89_row0_col8, #T_4ef89_row0_col9, #T_4ef89_row0_col10, #T_4ef89_row0_col11, #T_4ef89_row0_col12, #T_4ef89_row0_col13, #T_4ef89_row0_col14, #T_4ef89_row0_col15, #T_4ef89_row0_col16, #T_4ef89_row0_col17, #T_4ef89_row0_col18, #T_4ef89_row1_col4, #T_4ef89_row1_col5, #T_4ef89_row1_col6, #T_4ef89_row1_col7, #T_4ef89_row1_col8, #T_4ef89_row1_col9, #T_4ef89_row1_col10, #T_4ef89_row1_col11, #T_4ef89_row1_col12, #T_4ef89_row1_col13, #T_4ef89_row1_col14, #T_4ef89_row1_col15, #T_4ef89_row1_col16, #T_4ef89_row1_col17, #T_4ef89_row1_col18, #T_4ef89_row2_col4, #T_4ef89_row2_col5, #T_4ef89_row2_col6, #T_4ef89_row2_col7, #T_4ef89_row2_col8, #T_4ef89_row2_col9, #T_4ef89_row2_col10, #T_4ef89_row2_col11, #T_4ef89_row2_col12, #T_4ef89_row2_col13, #T_4ef89_row2_col14, #T_4ef89_row2_col15, #T_4ef89_row2_col16, #T_4ef89_row2_col17, #T_4ef89_row2_col18, #T_4ef89_row3_col4, #T_4ef89_row3_col5, #T_4ef89_row3_col6, #T_4ef89_row3_col7, #T_4ef89_row3_col8, #T_4ef89_row3_col9, #T_4ef89_row3_col10, #T_4ef89_row3_col11, #T_4ef89_row3_col12, #T_4ef89_row3_col13, #T_4ef89_row3_col14, #T_4ef89_row3_col15, #T_4ef89_row3_col16, #T_4ef89_row3_col17, #T_4ef89_row3_col18, #T_4ef89_row4_col4, #T_4ef89_row4_col5, #T_4ef89_row4_col6, #T_4ef89_row4_col7, #T_4ef89_row4_col8, #T_4ef89_row4_col9, #T_4ef89_row4_col10, #T_4ef89_row4_col11, #T_4ef89_row4_col12, #T_4ef89_row4_col13, #T_4ef89_row4_col14, #T_4ef89_row4_col15, #T_4ef89_row4_col16, #T_4ef89_row4_col17, #T_4ef89_row4_col18, #T_4ef89_row5_col4, #T_4ef89_row5_col5, #T_4ef89_row5_col6, #T_4ef89_row5_col7, #T_4ef89_row5_col8, #T_4ef89_row5_col9, #T_4ef89_row5_col10, #T_4ef89_row5_col11, #T_